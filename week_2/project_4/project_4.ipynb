# %%
# ATR Summary For Workers 

print("------------ATR SUMMARY----------")
def age ():
    a = int(input("Enter Your Age: "))
    return a 

def years ():
    y = int(input("Enter Your Years of Experience: "))
    return y 

while True:
    if years() > 25 and age() >= 55:
        print("You are an old worker\n")
        print("ATR = N5,600,000")
    elif years() > 20 and age() >= 45:
        print("ATR = N4,480,000")
    elif years()>10 and age>= 35:
        print("ATR = N1,500,000")
    else:
        print("ATR = N550,000")
    
    quit_input= input("Do you want to Quit Yes/No: ").strip().lower()
    if quit_input == 'yes':
        print("GOOD BYE")
        break
    elif quit_input == 'no':
        continue
# Out:
# ------------ATR SUMMARY----------
# You are an old worker
#
# ATR = N5,600,000
# GOOD BYE
