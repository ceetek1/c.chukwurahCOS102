# %%
# A calculator that performs CUBIC,QUADRATIC AND QUARTIC equations 
print("------------------------WELCOME------------------------")
# I Imported Numpy library to carry out the operation 
import numpy as np 

a = float(input("Enter input: ")) # Allows the users enter their value 
b = float(input("Enter input: "))
c = float(input("Enter input: "))
coefficients = (a,b,c)
roots = np.roots(coefficients)

print ("Roots of the quadratic equation:")
for root in roots:
    print(root)
# Out:
# ------------------------WELCOME------------------------
# Roots of the quadratic equation:
# 7.701562118716424
# 1.2984378812835757

# %%
a = float(input("Enter input: "))
b = float(input("Enter input: "))
c = float(input("Enter input: "))
d = float(input("Enter input: "))
coefficients = (a,b,c,d)
roots = np.roots(coefficients)

print ("Roots of the cubic equation:")
for root in roots:
    print(root)
# Out:
# Roots of the cubic equation:
# (-1.217525652084043+0j)
# (0.008762826042021127+0.906234596482378j)
# (0.008762826042021127-0.906234596482378j)

# %%
a = float(input("Enter input: "))
b = float(input("Enter input: "))
c = float(input("Enter input: "))
d = float(input("Enter input: "))
e = float(input("Enter input: "))
coefficients = (a,b,c,d,e)
roots = np.roots(coefficients)

print ("Roots of the quatric equation:")
for root in roots:
    print(root)
# Out:
# Roots of the quatric equation:
# (-7.488952190636201+0j)
# (0.19559148804338633+0.49361471650997757j)
# (0.19559148804338633-0.49361471650997757j)
# (-0.4736593568791468+0j)
