# %% [markdown]
# input : create a variable of the names
# process : create another variable that holds the first
# - then assign the second the variable created
# - then assign the first the second
# print : the other created variable and the first
# the names are swapped !

# %%
name1 = "charles"
name2 = "john"
print (f"None swapped {name1}, {name2}")

swap = name2 
name2 = name1
print (f"Name Swaped {swap},{name1}")
# Out:
# None swapped charles, john
# Name Swaped john,charles
