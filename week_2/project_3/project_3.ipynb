# %%
import pandas as pd 
girls_data = {
    'Name': ['Evelyn','Jessica','Somto','Edith','Liza','Madonna','Waje','Tola','Aisha','Latifa'],
    'Age': [17,16,17,18,16,18,17,20,19,17],
    'Height': [5.5,6.0,5.4,5.9,5.6,5.5,5.6,6.1,6.0,5.7,5.7,5.5],
    'Scores': [80,85,70,60,76,66,87,95,50,49] 
}
data_1 = pd.DataFrame(girls_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 girls_data = {
#       3     'Name': ['Evelyn','Jessica','Somto','Edith','Liza','Madonna','Waje','Tola','Aisha','Latifa'],
#       4     'Age': [17,16,17,18,16,18,17,20,19,17],
#       5     'Height': [5.5,6.0,5.4,5.9,5.6,5.5,5.6,6.1,6.0,5.7,5.7,5.5],
#       6     'Scores': [80,85,70,60,76,66,87,95,50,49]
#       7 }
#       8 data_1 = pd.DataFrame(girls_data)
#
# ModuleNotFoundError: No module named 'pandas'
