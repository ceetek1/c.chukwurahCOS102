# %% [markdown]
# BEGIN
#
# INPUT: number  of items
#
# PROCEDURE : Total number of items
#   FOR items BOUGHT :
#       IF SUM of ITEMS == PRICE
#           PRINT "THANK YOU FOR          PURCHACING COME AGAIN"
#   ELSE:
#       PRINT 'INSUFICIENT FUNDS'
# DISPLAY : CALL THE SECURITY!
#
# END
