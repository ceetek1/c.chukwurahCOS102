# %%
list = ['Anaconda',786, 2.23, 'Jupyter',70.2]
shortlist = [321, 'Python']

print (list)
print(list[0])
print(list[1:3])
print(list[2:])
print(shortlist * 2)
print(list + shortlist)
# Out:
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2]
# Anaconda
# [786, 2.23]
# [2.23, 'Jupyter', 70.2]
# [321, 'Python', 321, 'Python']
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2, 321, 'Python']

# %%
tuple = ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500)
s_tuple = ('Abekuta', 300, 'Ogbomosho')

# Prints the complete tuple 
print(tuple)

# Prints the last element of the tuple 
print (tuple[-1])

# Prints elements of the tuple starting from 2nd tii 3rd 
print (tuple[2:4])

# Prints elements of the tuple starting from 3rd element 
print (tuple[3:])

# Prints the contents of the tuple twice 
print (s_tuple * 3)

# Prints concatenated tuples 
print (tuple + s_tuple)
# Out:
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500)
# 500
# ('Oshogbo', 250)
# (250, 'Akure', 500)
# ('Abekuta', 300, 'Ogbomosho', 'Abekuta', 300, 'Ogbomosho', 'Abekuta', 300, 'Ogbomosho')
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500, 'Abekuta', 300, 'Ogbomosho')

# %%
str = input ("Enter your state of origin: ")

print ("Your state of origin is: ", str)
print( "This first character is: ", str[0])
print ("The characters staring from 3rd to 5th are: ", str[2:5])
print ( "The string staring from 3rd charcter is: ", str[2:])
print ("State of origin two times", str * 2)
# Out:
# Your state of origin is:  Anambra
# This first character is:  A
# The characters staring from 3rd to 5th are:  amb
# The string staring from 3rd charcter is:  ambra
# State of origin two times AnambraAnambra

# %%
# Input from user
m = float(input("Enter mass in kilogram: "))

# Constant value for the speed of light in m/s
c = 299792458

# Calculating energy using Einstein's equqation 
energy = m * c **2 

# Displaying the result 
print (f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# The energy equivalent to 4965.0 kg of mass is 4.462319462428299e+20 joules.

# %%
# Returns False as game_1 is not equal to game_2 

game_1 = 2
game_2 = 4
print (bool(game_1 == game_2))
# Or

print(game_1 == game_2)

# Returns false as a val is none 
val = None 
print(bool(val))

# Returns False as num is an empty sequence 
num = ()
print (bool(num))

# Returns true as age is boolean 
age = True 
print (bool(age))
# Out:
# False
# False
# False
# False
# True

# %%
# COnvert to int 

grade = int(70)
gpa = int(4.9)
cgpa = int ("4")

print (f"Grade = {grade}")
print (f"GPA = {gpa}")
print (f"CGPA = {cgpa}")
# Out:
# Grade = 70
# GPA = 4
# CGPA = 4

# %%
# Covert to float 
grade = float (97)
gpa = float(5)
cgpa = float("4.7")

print (f"Grade = {grade}")
print (f"GPA = {gpa}")
print (f"CGPA = {cgpa}")
# Out:
# Grade = 97.0
# GPA = 5.0
# CGPA = 4.7
