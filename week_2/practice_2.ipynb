# %%
# Python program to swap two cities 

#  To take inputs from the user 
city_1 = input('Enter name of city 1: ')
city_2 = input('Enter name of city 2:')

# Create a tmporary variable and swap the cities 
temp = city_1 
city_1 = city_2 
city_2 = temp 

print (f"The name of the city 1 after swapping is {city_1}")
print (f"The name of the city 1 after swapping is {city_2}")
# Out:
# The name of the city 1 after swapping is morocco
# The name of the city 1 after swapping is nigeria

# %%
# Program to Check if a number is positive , Negative or 0

num = float(input("Enter a number: "))
if num > 0:
    print ("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Positive number

# %%
# COUPE DE ESCRIVA 2023 : FOOTBALL PICKS 

print ("Welcome to the COUPE DE ESCIVA 2023: FOOTBALL PICS \n")

captain = {'Madibia': 'chubby Obiora-Okafo', 'Blue - jays': 'Christopher Uweh','Cirok': 'Timileyin Pearse/Izuako Jeremy','TSG Walkers: ': 'Ayomide Ojituku'}

goalkeepers = {'Madibia': 'chubby Obiora-Okafo', 'Blue - jays': 'Christopher Uweh','Cirok': 'Timileyin Pearse/Izuako Jeremy','TSG Walkers: ': 'Ayomide Ojituku'}

for pick in captain:
    print(pick, captain[pick])

print("\n")

for pick in goalkeepers:
    print(pick, goalkeepers[pick])
# Out:
# Welcome to the COUPE DE ESCIVA 2023: FOOTBALL PICS
#
# Madibia chubby Obiora-Okafo
# Blue - jays Christopher Uweh
# Cirok Timileyin Pearse/Izuako Jeremy
# TSG Walkers:  Ayomide Ojituku
#
#
# Madibia chubby Obiora-Okafo
# Blue - jays Christopher Uweh
# Cirok Timileyin Pearse/Izuako Jeremy
# TSG Walkers:  Ayomide Ojituku
