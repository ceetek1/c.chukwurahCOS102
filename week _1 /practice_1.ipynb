# %%
# Integer Number 
num = 100
print (num)
print('Data type of variables num is', type(num))


# Float 
fnum = 34.45
print (fnum)
print ('Data Type of variables fnum is',type(fnum))


# Complex Number 
cnum = 3 + 4j
print (cnum)
print ('Data Type of variable cnum is', type(cnum))
# Out:
# 100
# Data type of variables num is <class 'int'>
# 34.45
# Data Type of variables fnum is <class 'float'>
# (3+4j)
# Data Type of variable cnum is <class 'complex'>
